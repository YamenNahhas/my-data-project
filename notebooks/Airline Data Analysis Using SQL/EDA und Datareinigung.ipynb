# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import sqlite3
pd.set_option('display.precision', 2)

# %%
#connection to databank
conn = sqlite3.connect("../../data/raw/airlines-dataset/travel.sqlite")
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
tabels = cursor.fetchall()

print(tabels)
# Out:
# [('aircrafts_data',), ('airports_data',), ('boarding_passes',), ('bookings',), ('flights',), ('seats',), ('ticket_flights',), ('tickets',)]

# %%
for tabel in tabels:
    table_name = tabel[0]
    print('table name:', table_name)
    df_tabel = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
    display(df_tabel)
    print('\n')
# Out:
# table name: aircrafts_data
#   aircraft_code                                              model  range
# 0           773    {"en": "Boeing 777-300", "ru": "Боинг 777-300"}  11100
# 1           763    {"en": "Boeing 767-300", "ru": "Боинг 767-300"}   7900
# 2           SU9  {"en": "Sukhoi Superjet-100", "ru": "Сухой Суп...   3000
# 3           320  {"en": "Airbus A320-200", "ru": "Аэробус A320-...   5700
# 4           321  {"en": "Airbus A321-200", "ru": "Аэробус A321-...   5600
# 5           319  {"en": "Airbus A319-100", "ru": "Аэробус A319-...   6700
# 6           733    {"en": "Boeing 737-300", "ru": "Боинг 737-300"}   4200
# 7           CN1  {"en": "Cessna 208 Caravan", "ru": "Сессна 208...   1200
# 8           CR2  {"en": "Bombardier CRJ-200", "ru": "Бомбардье ...   2700
# table name: airports_data
#     airport_code                                       airport_name  \
# 0            YKS          {"en": "Yakutsk Airport", "ru": "Якутск"}
# ...

# %%
#Die explorative Datenanalyse (EDA)
for tabel in tabels:
    table_name = tabel[0]
    print('table name:', table_name)
    df_tabel = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
    display(
        "Shape",
        df_tabel.shape,
    "Description",
    df_tabel.describe().round(2).T,
    "Duplicates",
    df_tabel.duplicated().sum(),
    )


    overview = pd.DataFrame(
        {
            "Data Types": df_tabel.dtypes,
            "Missing Values": df_tabel.isnull().sum(),
            "Unique Values": df_tabel.nunique(),
            "Sample Values": [df_tabel[col].sample(3).tolist() for col in df_tabel.columns]
        })
    display(overview)
    print('missing values')
    display(df_tabel.isna().sum())
    print('\n'*2)
# Out:
# table name: aircrafts_data
# 'Shape'
# (9, 3)
# 'Description'
#        count     mean      std     min     25%     50%     75%      max
# range    9.0  5344.44  3013.76  1200.0  3000.0  5600.0  6700.0  11100.0
# 'Duplicates'
# np.int64(0)
#               Data Types  Missing Values  Unique Values  \
# aircraft_code     object               0              9
# model             object               0              9
# range              int64               0              9
#
#                                                    Sample Values
# aircraft_code                                    [733, CR2, 320]
# model          [{"en": "Boeing 767-300", "ru": "Боинг 767-300...
# range                                        [11100, 4200, 1200]
# missing values
# aircraft_code    0
# model            0
# range            0
# dtype: int64
# table name: airports_data
# 'Shape'
# (104, 5)
# 'Description'
#              count unique                                        top freq
# ...

# %%
#
numeric_to_categoric_columns = ['flight_id', 'flight_no']
date_columns = ['scheduled_departure', 'scheduled_arrival', 'actual_departure', 'actual_arrival', 'book_date']
for tabel in tabels:
    table_name = tabel[0]
    print('table name:', table_name)
    df_tabel = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
    for column in numeric_to_categoric_columns:
        if column in df_tabel.columns:
            df_tabel[column] = df_tabel[column].astype('category')
    if 'coordinates' in  df_tabel.columns:
        df_tabel[['longitude', 'latitude']] = (df_tabel['coordinates'].str.strip('()').str.split(',', expand=True).astype(float))
    object_columns = df_tabel.select_dtypes(include=['object']).columns.tolist()
    for column in object_columns:
        df_tabel[column]=df_tabel[column].astype('category')
    display(df_tabel.dtypes)
    display(df_tabel)
    print('\n'*2)
# Out:
# table name: aircrafts_data
# aircraft_code    category
# model            category
# range               int64
# dtype: object
#   aircraft_code                                              model  range
# 0           773    {"en": "Boeing 777-300", "ru": "Боинг 777-300"}  11100
# 1           763    {"en": "Boeing 767-300", "ru": "Боинг 767-300"}   7900
# 2           SU9  {"en": "Sukhoi Superjet-100", "ru": "Сухой Суп...   3000
# 3           320  {"en": "Airbus A320-200", "ru": "Аэробус A320-...   5700
# 4           321  {"en": "Airbus A321-200", "ru": "Аэробус A321-...   5600
# 5           319  {"en": "Airbus A319-100", "ru": "Аэробус A319-...   6700
# 6           733    {"en": "Boeing 737-300", "ru": "Боинг 737-300"}   4200
# 7           CN1  {"en": "Cessna 208 Caravan", "ru": "Сессна 208...   1200
# 8           CR2  {"en": "Bombardier CRJ-200", "ru": "Бомбардье ...   2700
# table name: airports_data
# airport_code    category
# airport_name    category
# city            category
# ...

# %%
for tabel in tabels:
    table_name = tabel[0]
    df_tabel = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)

# %%
#closing the connection to databank
#conn.close()
